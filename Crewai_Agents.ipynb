# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad1sys/agentic_ai/blob/main/Crewai_Agents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade crewai crewai-tools

# %%
# !pip install --upgrade pip

# %%
pip install --upgrade crewai

# %%
# !crewai create crew ai-latest-development
# Out:
# Creating folder ai_latest_development...
# Cache expired or not found. Fetching provider data from the web...
# ...
# Select a provider to set up:
# 1. openai
# 2. anthropic
# 3. gemini
# 4. nvidia_nim
# 5. groq
# 6. ollama
# 7. watson
# 8. bedrock
# 9. azure
# 10. cerebras
# 11. sambanova
# 12. other
# q. Quit
# Enter the number of your choice or 'q' to quit: 3
# Select a model to use for Gemini:
# 1. gemini/gemini-1.5-flash
# 2. gemini/gemini-1.5-pro
# 3. gemini/gemini-gemma-2-9b-it
# 4. gemini/gemini-gemma-2-27b-it
# q. Quit
# Enter the number of your choice or 'q' to quit: 1
# Enter your GEMINI API key (press Enter to skip): AIzaSyCLsCjDDLdUPzab7bRUs4ps8ch6o7vmves
# API keys and model saved to .env file
# Selected model: gemini/gemini-1.5-flash
#   - Created ai_latest_development/.gitignore
#   - Created ai_latest_development/pyproject.toml
#   - Created ai_latest_development/README.md
#   - Created ai_latest_development/knowledge/user_preference.txt
# ...

# %%
# !ls
# Out:
# ai_latest_development  sample_data

# %%
cd /content/ai_latest_development/src/ai_latest_development
# Out:
# /content/ai_latest_development/src/ai_latest_development

# %%
# !ls
# Out:
# config	crew.py  __init__.py  main.py  tools

# %%
# !uv run main.py
# Out:
# Streaming output truncated to the last 5000 lines.
# chroma-hnswlib ------------------------------ 2.12 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.09 MiB/2.35 MiB
# langchain-community ------------------------------ 1.03 MiB/2.40 MiB
# shapely    ------------------------------ 2.16 MiB/2.41 MiB
# Building ai-latest-development @ file:///content/ai_latest_development
# ⠼ Preparing packages... (126/212)
# portalocker ------------------------------ 14.94 KiB/17.99 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.92 KiB/18.03 KiB
# jsonschema-specifications ------------------------------ 16.00 KiB/18.03 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 16.00 KiB/18.09 KiB
# schema     ------------------------------ 14.91 KiB/18.20 KiB
# python-dotenv ------------------------------ 14.96 KiB/19.40 KiB
# json-repair ------------------------------ 16.00 KiB/19.44 KiB
# ...
